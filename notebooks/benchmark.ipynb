# %% [markdown]
# # Plantilla: benchmarking de LLMs
# Usa `greenllm` para ejecutar una comparativa entre diferentes LLMs y generar resultados.

# %%
from framework.src.greenllm.runners.inference_runner import run_measurement
from framework.src.greenllm.metrics.metrics import compute_metrics
res = run_measurement('TinyLlama/TinyLlama-1.1B-Chat-v1.0', '../data/prompts/prompt_set_small.txt', max_new_tokens=32, meter_name='none', carbon_intensity=300)
met = compute_metrics(res)
res | met
